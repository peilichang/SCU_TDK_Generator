yJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjoiODE1NWM3ZDktZDJhMi00ODZiLTk5ZjgtYzljZjJkZWJlYmUwIiwiZXhwIjoxNjY3NTAxMjQ4fQ.xKy_3rztEgGXn5KHHDB-kCeW871xLnVqhDHviyQguFQ; kvcd=1667328454996; _uetsid=9b0a2f005a1511ed82ae2d6d96b96da7; _uetvid=5e31df30324b11ed967f45affbddc300; __hssc=240018588.2.1667328439890; amp_276990=Ryu8NaOuUBKIYmsvSi4sT5.ODE1NWM3ZDktZDJhMi00ODZiLTk5ZjgtYzljZjJkZWJlYmUw..1ggq89ejr.1ggq8l9pq.2a.0.2a; _gat_UA-16137731-1=1; _clsk=dikgmk|1667328816098|5|1|b.clarity.ms/collect',
        "authorization": "Bearer app#tier1__17af8e52135c27850e84496bbbc276f242652fc3"
    }

    url = "https://app.neilpatel.com/api/match_keywords"
    form_data = {"keywords":[keyword],"locId":"2158","language":"zh_tw","sortby":"-searchVolume","limit":500,"previousKey":0,"filters":{}}
    str_request_payload = json.dumps(form_data).encode("utf-8")
    res = requests.post(url, headers = headers, data=str_request_payload)
    data = json.loads(res.text)
    return data

# %%
keyword_list = keyword_df["keyword"][0:5].tolist()
extend_keyword = pd.DataFrame(columns=["keyword", "volume", "SEO Difficulty", "KEI", "source", "CPC", "Paid Difficulty"])

for search in keyword_list:
    result = keyword_colloct(search)
    for each in range(len(result["suggestions"])):
        keyword = result["suggestions"][each]
        space_remove = keyword["keyword"].replace(" ", "")
            
        if (keyword["volume"] > 0) & (space_remove not in extend_keyword["keyword"].tolist()): #403
            KEI = keyword["volume"]/keyword["sd"]
            extend_keyword.loc[len(extend_keyword)] = [keyword["keyword"].replace(" ", ""),keyword["volume"],keyword["sd"], KEI, search,keyword["cpc"],keyword["pd"]]
extend_keyword

# %% [markdown]
# # 資料匯入－初始關鍵字清單¶
# - 有先將初始關鍵清單在 Gephi 處理
# - keyword_classify 為處理完的 data
# - Id 中包含初始關鍵字（is_keyword=1）、關聯字詞（is_keyword=2）
# - modularity_class 代表分類結果

# %%
import requests
import json
import pandas as pd

# %%
keyword_classify = pd.read_csv("/content/drive/MyDrive/程式/keyword_classify(Modularity).csv")
keyword_classify
# Out:
#          Id  Label  timeset  frequency  is_keyword  volume  cpc  \
# 0        麵包    NaN      NaN     1021.0         2.0     NaN  NaN
# 1        口味    NaN      NaN      967.0         2.0     NaN  NaN
# 2         1    NaN      NaN      947.0         2.0     NaN  NaN
# 3        原味    NaN      NaN      918.0         2.0     NaN  NaN
# 4        乳酪    NaN      NaN      868.0         2.0     NaN  NaN
# ...     ...    ...      ...        ...         ...     ...  ...
# 22548   山豬肉    NaN      NaN        NaN         NaN     NaN  NaN
# 22549  烤焙果雞    NaN      NaN        NaN         NaN     NaN  NaN
# 22550   單點類    NaN      NaN        NaN         NaN     NaN  NaN
# 22551   木托盤    NaN      NaN        NaN         NaN     NaN  NaN
# 22552    時蔬    NaN      NaN        NaN         NaN     NaN  NaN
#
#        seo difficulty  paid difficulty  indegree  outdegree  degree  \
# 0                 NaN              NaN         0        126     126
# ...

# %%
# 取出 keyword_classify 中的關鍵字
initial_keyword = keyword_classify[keyword_classify['is_keyword']==1].reset_index(drop=True)
initial_keyword
# Out:
#         Id  Label  timeset  frequency  is_keyword  volume        cpc  \
# 0     貝果熱量    NaN      NaN        NaN         1.0  3600.0  11.462508
# 1     貝果做法    NaN      NaN        NaN         1.0  3600.0   8.539568
# 2     貝果食譜    NaN      NaN        NaN         1.0  2900.0   5.638917
# 3     貝果貝果    NaN      NaN        NaN         1.0  1600.0  16.716158
# 4    貝果專賣店    NaN      NaN        NaN         1.0  1300.0  54.128510
# ..     ...    ...      ...        ...         ...     ...        ...
# 128  貝果的做法    NaN      NaN        NaN         1.0    70.0   0.000000
# 129   貝果配方    NaN      NaN        NaN         1.0    70.0  14.337687
# 130   巨蛋貝果    NaN      NaN        NaN         1.0    70.0   8.278478
# 131   脆皮貝果    NaN      NaN        NaN         1.0    70.0  33.113912
# 132   貝果套餐    NaN      NaN        NaN         1.0    70.0  24.357830
#
#      seo difficulty  paid difficulty  indegree  outdegree  degree  \
# 0              70.0             34.0       112          0     112
# ...

# %% [markdown]
# ## 將不同類別關鍵字分開儲存

# %%
# 貝果口味相關
bagel_flavor = initial_keyword[initial_keyword['modularity_class']==1].copy()
bagel_flavor = bagel_flavor.drop(columns=['Label','timeset','frequency','is_keyword']).reset_index(drop=True)
bagel_flavor
# Out:
#          Id  volume        cpc  seo difficulty  paid difficulty  indegree  \
# 0      藍莓貝果   720.0   9.870493            45.0             96.0       116
# 1      起司貝果   480.0  17.989770            57.0             97.0       116
# 2    藍莓貝果食譜   260.0   6.024185            29.0             35.0       124
# 3    切達起司貝果   260.0   0.000000            59.0             60.0       120
# 4      乳酪貝果   260.0  14.414104            46.0             99.0       125
# 5   bagel貝果   170.0  42.029196            47.0             88.0       118
# 6      芝麻貝果   170.0   7.049442            67.0             99.0       117
# 7    起司火腿貝果   140.0  40.118778            65.0             71.0       114
# 8     貝果乳酪醬   140.0  16.779838            69.0             80.0       105
# 9      草莓貝果   110.0   7.164067            55.0             63.0       110
# 10   藍莓乳酪貝果    90.0   1.773505            37.0             17.0       117
# 11    起司q貝果    90.0   0.000000            42.0             36.0       109
# ...

# %%
# 貝果熱量
bagel_calorie = initial_keyword[initial_keyword['modularity_class']==3]

# %%
# bagel_flavor.to_csv("/content/drive/MyDrive/程式/bagel_flavor.csv")
